# %%
import osmnx as ox
import networkx as nx

# %%
nanshan_graph_drive=ox.graph_from_place("南山区, 深圳, 中国", which_result=1, network_type="drive")

nanshan_graph_drive

# %%
ox.plot_graph(nanshan_graph_drive)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
ox.basic_stats(nanshan_graph_drive)
# Out:
# {'n': 6390,
#  'm': 13443,
#  'k_avg': 4.2075117370892015,
#  'edge_length_total': 2124237.5490000043,
#  'edge_length_avg': 158.01811716134824,
#  'streets_per_node_avg': 3.0247261345852894,
#  'streets_per_node_counts': {0: 0,
#   1: 635,
#   2: 28,
#   3: 4323,
#   4: 1358,
#   5: 40,
#   6: 6},
#  'streets_per_node_proportions': {0: 0.0,
#   1: 0.09937402190923318,
#   2: 0.004381846635367762,
#   3: 0.6765258215962441,
#   4: 0.21251956181533646,
#   5: 0.006259780907668232,
#   6: 0.0009389671361502347},
#  'intersection_count': 5755,
#  'street_length_total': 1546316.9720000008,
#  'street_segment_count': 9627,
#  'street_length_avg': 160.62293258543687,
#  'circuity_avg': 1.0807405037662599,
#  'self_loop_proportion': 0.001765866832865898}

# %%
nanshan_line_graph_drive=nx.line_graph(nanshan_graph_drive)

len(nanshan_line_graph_drive.nodes)
# Out:
# 13443

# %%
nx.write_gpickle(nanshan_graph_drive, path="../data/nanshan_graph_drive.pkl")
nx.write_gpickle(nanshan_line_graph_drive, path="../data/nanshan_line_graph_drive.pkl")
