# %%
import pandas as pd
import os

CACHE_PATH="../../Bigscity-LibCity/libcity/cache/"

# %pwd
# Out:
# '/home/cseadmin/dz/TrafficFlowModel/model'

# %%
# sz_taxi_5day

run_id_list=os.listdir(CACHE_PATH)[1:]

df_eval=pd.DataFrame(columns=["MAE", "MAPE", "MSE", "RMSE", "Masked MAE", "Masked MAPE", "Masked MSE", "Masked RMSE", "R2", "EVAR"])

for run_id in run_id_list:
    for file in os.listdir(os.path.join(CACHE_PATH, str(run_id), "evaluate_cache")):
        if file.endswith(".csv"):
            csv_res=file
    model_name=csv_res.split("_")[-3]
    df_eval_res=pd.read_csv(os.path.join(CACHE_PATH, str(run_id), "evaluate_cache", csv_res))
    
    df_eval.loc[model_name]=df_eval_res.mean().values

df_eval
# Out:
#                   MAE  MAPE         MSE       RMSE  Masked MAE  Masked MAPE  \
# AGCRN        4.274487   inf   90.082411   9.359016    4.872844     1.004101
# AutoEncoder  4.765535   inf  109.586338  10.333536    5.461414     1.062234
# FNN          4.252304   inf  107.891017  10.270195    5.489260     0.734776
# RNN          4.671350   inf  106.618292  10.192023    5.389651     1.053383
# GWNET        2.919638   inf   35.970539   5.988635    3.253735     0.719556
# MTGNN        5.306060   inf  106.923713  10.119259    5.534398     1.390216
# Seq2Seq      4.658527   inf  103.262320  10.032472    5.329687     1.080802
# STGCN        4.826795   inf   87.597886   9.298909    5.571309     1.442719
# STSGCN       4.485576   inf  118.685937  10.759670    5.743781     0.740742
# ToGCN        5.558411   inf  107.180817  10.229315    5.691583     1.557375
# DCRNN        4.542408   inf  106.194082  10.297803    5.263614     0.939877
# ...

# %%
# sz_taxi_202006

run_id_list=os.listdir(CACHE_PATH)[1:]

df_eval=pd.DataFrame(columns=["MAE", "MAPE", "MSE", "RMSE", "Masked MAE", "Masked MAPE", "Masked MSE", "Masked RMSE", "R2", "EVAR"])

for run_id in run_id_list:
    for file in os.listdir(os.path.join(CACHE_PATH, run_id, "evaluate_cache")):
        if file.endswith(".csv"):
            csv_res=file
    model_name=csv_res.split("_")[-4]
    df_eval_res=pd.read_csv(os.path.join(CACHE_PATH, run_id, "evaluate_cache", csv_res))
    
    df_eval.loc[model_name]=df_eval_res.mean().values

df_eval
# Out:
#                     MAE  MAPE           MSE        RMSE  Masked MAE  \
# STGCN          5.158203   inf     95.891096    9.717272    5.810949
# ToGCN          9.688037   inf    188.814398   13.740707    9.031057
# Seq2Seq        9.275260   inf    305.144669   17.465466   10.271731
# RNN            9.118608   inf    303.928307   17.433128   10.138094
# AutoEncoder   10.339843   inf    388.007884   19.697663   11.519646
# MTGNN          4.005621   inf     62.905317    7.927934    4.608485
# FNN            9.076950   inf    358.464480   18.929037   10.675523
# AGCRN          4.080020   inf     61.057433    7.813271    4.566071
# DCRNN          4.420935   inf     78.294429    8.846667    4.967698
# ASTGCN         3.281325   inf     66.315501    5.756425    3.597857
# MSTGCN         2.349216   inf     34.900022    3.746542    2.556219
# GWNET          3.748246   inf     59.090234    7.684821    4.324531
# STSGCN        10.584228   inf    445.971474   21.117800   12.251219
# ...

# %%
# sz_taxi_202006 4 4

run_id_list=os.listdir(CACHE_PATH)[1:]

df_eval=pd.DataFrame(columns=["MAE", "MAPE", "MSE", "RMSE", "Masked MAE", "Masked MAPE", "Masked MSE", "Masked RMSE", "R2", "EVAR"])

for run_id in run_id_list:
    if not os.listdir(os.path.join(CACHE_PATH, run_id, "evaluate_cache")):
        continue
    for file in os.listdir(os.path.join(CACHE_PATH, run_id, "evaluate_cache")):
        if file.endswith(".csv"):
            csv_res=file
    model_name=csv_res.split("_")[-4]
    df_eval_res=pd.read_csv(os.path.join(CACHE_PATH, run_id, "evaluate_cache", csv_res))
    
    df_eval.loc[model_name]=df_eval_res.mean().values

df_eval
# Out:
#                    MAE  MAPE           MSE        RMSE  Masked MAE  \
# Seq2Seq       9.039898   inf    289.190948   17.003249    9.965468
# CONVGCN      57.448203   inf  11268.911377  106.148260   57.390455
# RNN           9.107327   inf    270.698135   16.452799    9.874097
# ASTGCN        8.367975   inf    195.558754   13.971000    9.312792
# ToGCN         9.818080   inf    213.795460   14.621634    9.090293
# MSTGCN        7.002821   inf    121.952013   11.040104    7.619031
# FNN           9.766923   inf    396.210556   19.899239   11.494213
# GWNET         3.848504   inf     59.726578    7.725074    4.409513
# AGCRN         5.372940   inf     98.803316    9.937461    5.825678
# MTGNN         3.840988   inf     57.180310    7.559726    4.404340
# AutoEncoder  10.059541   inf    369.365585   19.218768   11.230853
# DCRNN         6.947852   inf    181.619431   13.473693    7.517072
#
#              Masked MAPE    Masked MSE  Masked RMSE         R2       EVAR
# ...

# %%
# sz_taxi_202006_5min 12 12

run_id_list=os.listdir(CACHE_PATH)[1:]

df_eval=pd.DataFrame(columns=["MAE", "MAPE", "MSE", "RMSE", "Masked MAE", "Masked MAPE", "Masked MSE", "Masked RMSE", "R2", "EVAR"])

for run_id in run_id_list:
    if not os.listdir(os.path.join(CACHE_PATH, run_id, "evaluate_cache")):
        continue
    for file in os.listdir(os.path.join(CACHE_PATH, run_id, "evaluate_cache")):
        if file.endswith(".csv"):
            csv_res=file
    model_name=csv_res.split("_")[-4]
    df_eval_res=pd.read_csv(os.path.join(CACHE_PATH, run_id, "evaluate_cache", csv_res))
    
    df_eval.loc[model_name]=df_eval_res.mean().values

df_eval.sort_values("Masked MAPE")
# Out:
#                   MAE  MAPE         MSE       RMSE  Masked MAE  Masked MAPE  \
# GWNET        2.142696   inf   11.216906   3.345144    2.351962     0.418610
# DCRNN        2.248979   inf   11.527182   3.393559    2.447225     0.456523
# AGCRN        2.250134   inf   12.124443   3.479094    2.435056     0.463321
# MTGNN        2.385814   inf   13.924886   3.726723    2.626406     0.472645
# STGCN        2.305517   inf   13.550445   3.671893    2.623388     0.497396
# MSTGCN       2.754093   inf   15.763491   3.969260    3.024496     0.689641
# RNN          3.111372   inf   22.018843   4.692415    3.408879     0.747481
# FNN          5.235084   inf   82.001604   9.049153    5.953043     0.882703
# STSGCN       6.266485   inf  116.568674  10.796683    6.933876     0.896442
# ASTGCN       3.863572   inf   33.042567   5.747362    4.213428     0.959660
# AutoEncoder  6.190258   inf  101.076906  10.053691    6.564710     1.250405
# ...

# %%
# sz_taxi_202006_5min 12 12 step1

run_id_list=os.listdir(CACHE_PATH)[1:]

df_eval=pd.DataFrame(columns=["MAE", "MAPE", "MSE", "RMSE", "Masked MAE", "Masked MAPE", "Masked MSE", "Masked RMSE", "R2", "EVAR"])

for run_id in run_id_list:
    if not os.listdir(os.path.join(CACHE_PATH, run_id, "evaluate_cache")):
        continue
    for file in os.listdir(os.path.join(CACHE_PATH, run_id, "evaluate_cache")):
        if file.endswith(".csv"):
            csv_res=file
    model_name=csv_res.split("_")[-4]
    df_eval_res=pd.read_csv(os.path.join(CACHE_PATH, run_id, "evaluate_cache", csv_res))
    
    df_eval.loc[model_name]=df_eval_res.iloc[0].values

df_eval.sort_values("Masked MAPE")
# Out:
#                   MAE  MAPE         MSE       RMSE  Masked MAE  Masked MAPE  \
# GWNET        1.905297   inf    8.679706   2.946134    2.065669     0.376403
# AGCRN        2.056668   inf   10.038654   3.168384    2.222965     0.425100
# STGCN        1.963420   inf    9.498472   3.081959    2.222669     0.431783
# MTGNN        2.163136   inf   10.796456   3.285796    2.354454     0.444494
# DCRNN        2.110828   inf   10.068755   3.173130    2.268841     0.448339
# MSTGCN       2.682516   inf   14.594806   3.820315    2.941385     0.682665
# RNN          3.119855   inf   22.094955   4.700527    3.417663     0.750987
# STSGCN       6.268793   inf  116.548851  10.795779    6.936953     0.895777
# FNN          4.839934   inf   63.957287   7.997330    5.431410     0.920296
# ASTGCN       3.948979   inf   33.755222   5.809925    4.282783     0.996212
# AutoEncoder  6.192744   inf  101.105690  10.055133    6.566908     1.249662
# ...

# %%
# sz_taxi_202006_5min 12 12 drop 23:00~

df_eval=pd.DataFrame(columns=["MAE", "MAPE", "MSE", "RMSE", "Masked MAE", "Masked MAPE", "Masked MSE", "Masked RMSE", "R2", "EVAR"])

os.chdir("/home/cseadmin/dz/Bigscity-LibCity")
for log_file in os.listdir("log_sz_taxi_202006"):
    model=log_file.split("_")[1].split(".")[0]
    with open(os.path.join("log_sz_taxi_202006", log_file)) as f:
        for line in f.readlines():
            if "INFO" not in line:
                continue
            if line.split("INFO")[1].startswith(" - Evaluate result"):
                res_path=line.split(" ")[-1].strip()
                break
    df_eval_res=pd.read_csv(res_path)
    
    df_eval.loc[model]=df_eval_res.mean().values
    
df_eval.sort_values("Masked MAPE")
# Out:
#                   MAE  MAPE        MSE      RMSE  Masked MAE  Masked MAPE  \
# GWNET        2.154081   inf  11.071333  3.323448    2.370429     0.442740
# MTGNN        2.257224   inf  12.141762  3.480952    2.496198     0.462327
# DCRNN        2.200221   inf  11.034395  3.320004    2.409839     0.463776
# AGCRN        2.222308   inf  11.238118  3.350460    2.402686     0.481806
# STGCN        2.240672   inf  12.580816  3.538950    2.583992     0.506951
# GRU          2.910206   inf  19.396664  4.404157    3.220675     0.703136
# MSTGCN       2.851515   inf  16.389740  4.047523    3.120554     0.747849
# STSGCN       5.537956   inf  79.504955  8.916552    6.104897     0.865794
# FNN          4.699834   inf  58.986231  7.678108    5.336428     0.866719
# ASTGCN       3.372940   inf  24.157639  4.914566    3.706323     0.877116
# LSTM         4.468870   inf  44.571861  6.675980    4.669395     1.091888
# Seq2Seq      4.869545   inf  53.343612  7.298692    5.091221     1.173621
# ...

# %%
# sz_taxi_202006_5min 12 12 drop <5

df_eval=pd.DataFrame(columns=["MAE", "MAPE", "MSE", "RMSE", "Masked MAE", "Masked MAPE", "Masked MSE", "Masked RMSE", "R2", "EVAR"])

os.chdir("/home/cseadmin/dz/Bigscity-LibCity")
for log_file in os.listdir("log_sz_taxi_202006"):
    model=log_file.split("_")[1].split(".")[0]
    with open(os.path.join("log_sz_taxi_202006", log_file)) as f:
        for line in f.readlines():
            if "INFO" not in line:
                continue
            if line.split("INFO")[1].startswith(" - Evaluate result"):
                res_path=line.split(" ")[-1].strip()
                break
    df_eval_res=pd.read_csv(res_path)
    
    df_eval.loc[model]=df_eval_res.mean().values
    
df_eval.sort_values("Masked MAPE")
# Out:
#                   MAE  MAPE        MSE      RMSE  Masked MAE  Masked MAPE  \
# GWNET        2.166391   inf  11.190103  3.341490    2.377223     0.443914
# MTGNN        2.250929   inf  11.969164  3.456292    2.488430     0.461521
# DCRNN        2.206002   inf  11.112172  3.331797    2.417232     0.465271
# AGCRN        2.206120   inf  11.180865  3.342006    2.397107     0.473443
# STGCN        2.266915   inf  12.865397  3.578335    2.607502     0.513928
# GRU          2.922758   inf  19.355133  4.399441    3.235461     0.712573
# MSTGCN       2.842631   inf  16.254546  4.030846    3.115480     0.743935
# FNN          4.701920   inf  59.060159  7.682834    5.338780     0.866330
# STSGCN       5.538046   inf  79.419116  8.911734    6.101121     0.868200
# ASTGCN       3.386004   inf  24.132977  4.912342    3.700989     0.873141
# LSTM         4.461636   inf  43.922362  6.627336    4.668649     1.100260
# AutoEncoder  5.358660   inf  64.156638  8.009772    5.598805     1.219152
# ...

# %% [markdown]
# flow
#
# ```
# Model  AGCRN  Best Results:
# Epoch 68:
# |Step 1 | MAPE: val: 31.886, test: 33.232; MAE: val: 3.614, test: 3.409; RMSE: val: 4.762, test: 4.370;
# |Step 2 | MAPE: val: 32.360, test: 33.486; MAE: val: 3.685, test: 3.454; RMSE: val: 4.886, test: 4.452;
# |Step 3 | MAPE: val: 32.897, test: 33.719; MAE: val: 3.766, test: 3.500; RMSE: val: 5.012, test: 4.532;
# |Step 4 | MAPE: val: 33.374, test: 33.943; MAE: val: 3.837, test: 3.542; RMSE: val: 5.123, test: 4.605;
# |Step 5 | MAPE: val: 33.998, test: 34.407; MAE: val: 3.917, test: 3.595; RMSE: val: 5.249, test: 4.684;
# |Step 6 | MAPE: val: 34.314, test: 34.722; MAE: val: 3.973, test: 3.637; RMSE: val: 5.347, test: 4.751;
# |Step 7 | MAPE: val: 34.721, test: 35.111; MAE: val: 4.033, test: 3.687; RMSE: val: 5.447, test: 4.827;
# |Step 8 | MAPE: val: 35.089, test: 35.542; MAE: val: 4.089, test: 3.740; RMSE: val: 5.545, test: 4.907;
# |Step 9 | MAPE: val: 35.549, test: 35.947; MAE: val: 4.153, test: 3.796; RMSE: val: 5.638, test: 4.989;
# |Step 10 | MAPE: val: 35.836, test: 36.123; MAE: val: 4.204, test: 3.838; RMSE: val: 5.721, test: 5.066;
# |Step 11 | MAPE: val: 36.328, test: 36.467; MAE: val: 4.275, test: 3.888; RMSE: val: 5.831, test: 5.153;
# |Step 12 | MAPE: val: 36.737, test: 36.811; MAE: val: 4.328, test: 3.933; RMSE: val: 5.903, test: 5.223;
#
# Model  GWN  Best Results:
# Epoch 44:
# |Step 1 | MAPE: val: 33.036, test: 34.433; MAE: val: 3.680, test: 3.478; RMSE: val: 4.791, test: 4.445;
# |Step 2 | MAPE: val: 34.051, test: 35.183; MAE: val: 3.795, test: 3.561; RMSE: val: 4.950, test: 4.561;
# |Step 3 | MAPE: val: 34.243, test: 35.316; MAE: val: 3.835, test: 3.593; RMSE: val: 5.034, test: 4.618;
# |Step 4 | MAPE: val: 34.366, test: 35.287; MAE: val: 3.891, test: 3.628; RMSE: val: 5.148, test: 4.696;
# |Step 5 | MAPE: val: 34.823, test: 36.001; MAE: val: 3.954, test: 3.685; RMSE: val: 5.271, test: 4.769;
# |Step 6 | MAPE: val: 35.695, test: 36.687; MAE: val: 4.078, test: 3.750; RMSE: val: 5.484, test: 4.857;
# |Step 7 | MAPE: val: 35.668, test: 36.066; MAE: val: 4.101, test: 3.737; RMSE: val: 5.524, test: 4.888;
# |Step 8 | MAPE: val: 36.163, test: 36.391; MAE: val: 4.189, test: 3.800; RMSE: val: 5.683, test: 4.997;
# |Step 9 | MAPE: val: 37.690, test: 38.094; MAE: val: 4.322, test: 3.932; RMSE: val: 5.840, test: 5.141;
# |Step 10 | MAPE: val: 37.773, test: 37.702; MAE: val: 4.400, test: 3.930; RMSE: val: 6.012, test: 5.183;
# |Step 11 | MAPE: val: 38.505, test: 38.374; MAE: val: 4.495, test: 4.036; RMSE: val: 6.140, test: 5.341;
# |Step 12 | MAPE: val: 38.940, test: 38.985; MAE: val: 4.569, test: 4.108; RMSE: val: 6.273, test: 5.429;
#
# Model  LSTNet  Best Results:
# Epoch 200:
# |12    Horizon | MAPE: 34.052, 35.047; MAE: 3.945, 3.648; RMSE: 5.422, 4.819;
#
# Model  MTGNN  Best Results:
# Epoch 78:
# |Step 1 | MAPE: val: 31.680, test: 32.777; MAE: val: 3.565, test: 3.350; RMSE: val: 4.667, test: 4.279;
# |Step 2 | MAPE: val: 32.839, test: 34.121; MAE: val: 3.726, test: 3.511; RMSE: val: 4.934, test: 4.522;
# |Step 3 | MAPE: val: 33.210, test: 34.345; MAE: val: 3.781, test: 3.535; RMSE: val: 5.015, test: 4.557;
# |Step 4 | MAPE: val: 33.275, test: 34.015; MAE: val: 3.807, test: 3.520; RMSE: val: 5.073, test: 4.553;
# |Step 5 | MAPE: val: 33.724, test: 34.267; MAE: val: 3.885, test: 3.560; RMSE: val: 5.205, test: 4.628;
# |Step 6 | MAPE: val: 34.653, test: 36.087; MAE: val: 3.997, test: 3.755; RMSE: val: 5.371, test: 4.880;
# |Step 7 | MAPE: val: 34.749, test: 35.199; MAE: val: 4.022, test: 3.671; RMSE: val: 5.425, test: 4.798;
# |Step 8 | MAPE: val: 35.228, test: 36.221; MAE: val: 4.091, test: 3.787; RMSE: val: 5.545, test: 4.950;
# |Step 9 | MAPE: val: 35.769, test: 35.852; MAE: val: 4.183, test: 3.772; RMSE: val: 5.685, test: 4.967;
# |Step 10 | MAPE: val: 35.645, test: 36.261; MAE: val: 4.162, test: 3.827; RMSE: val: 5.674, test: 5.042;
# |Step 11 | MAPE: val: 36.398, test: 36.522; MAE: val: 4.284, test: 3.866; RMSE: val: 5.857, test: 5.108;
# |Step 12 | MAPE: val: 36.778, test: 37.600; MAE: val: 4.312, test: 3.990; RMSE: val: 5.900, test: 5.283;
#
# Model  STNorm  Best Results:
# Epoch 61:
# |Step 1 | MAPE: val: 31.351, test: 32.265; MAE: val: 3.513, test: 3.303; RMSE: val: 4.599, test: 4.233;
# |Step 2 | MAPE: val: 32.041, test: 33.030; MAE: val: 3.597, test: 3.391; RMSE: val: 4.727, test: 4.354;
# |Step 3 | MAPE: val: 32.333, test: 33.092; MAE: val: 3.643, test: 3.404; RMSE: val: 4.809, test: 4.391;
# |Step 4 | MAPE: val: 32.910, test: 33.643; MAE: val: 3.714, test: 3.471; RMSE: val: 4.912, test: 4.478;
# |Step 5 | MAPE: val: 32.905, test: 33.620; MAE: val: 3.746, test: 3.510; RMSE: val: 5.001, test: 4.568;
# |Step 6 | MAPE: val: 33.554, test: 34.560; MAE: val: 3.809, test: 3.591; RMSE: val: 5.090, test: 4.661;
# |Step 7 | MAPE: val: 33.990, test: 34.923; MAE: val: 3.878, test: 3.635; RMSE: val: 5.200, test: 4.716;
# |Step 8 | MAPE: val: 34.487, test: 35.258; MAE: val: 3.936, test: 3.686; RMSE: val: 5.293, test: 4.824;
# |Step 9 | MAPE: val: 34.709, test: 35.399; MAE: val: 3.992, test: 3.721; RMSE: val: 5.401, test: 4.883;
# |Step 10 | MAPE: val: 35.040, test: 35.999; MAE: val: 4.037, test: 3.800; RMSE: val: 5.477, test: 5.001;
# |Step 11 | MAPE: val: 35.579, test: 36.152; MAE: val: 4.112, test: 3.825; RMSE: val: 5.579, test: 5.055;
# |Step 12 | MAPE: val: 36.224, test: 36.704; MAE: val: 4.201, test: 3.905; RMSE: val: 5.727, test: 5.185;
# ```

# %% [markdown]
# speed (avg=29.34)
#
# ```
# Model  AGCRN  Best Results:
# Epoch 195:
# |Step 1 | MAPE: val: 26.579, test: 23.834; MAE: val: 4.743, test: 4.642; RMSE: val: 6.701, test: 6.587;
# |Step 2 | MAPE: val: 26.844, test: 23.922; MAE: val: 4.781, test: 4.659; RMSE: val: 6.749, test: 6.604;
# |Step 3 | MAPE: val: 27.053, test: 23.986; MAE: val: 4.813, test: 4.674; RMSE: val: 6.788, test: 6.617;
# |Step 4 | MAPE: val: 27.274, test: 24.070; MAE: val: 4.846, test: 4.686; RMSE: val: 6.825, test: 6.629;
# |Step 5 | MAPE: val: 27.468, test: 24.141; MAE: val: 4.874, test: 4.701; RMSE: val: 6.862, test: 6.642;
# |Step 6 | MAPE: val: 27.687, test: 24.211; MAE: val: 4.902, test: 4.715; RMSE: val: 6.898, test: 6.656;
# |Step 7 | MAPE: val: 27.910, test: 24.252; MAE: val: 4.931, test: 4.725; RMSE: val: 6.936, test: 6.665;
# |Step 8 | MAPE: val: 28.079, test: 24.338; MAE: val: 4.954, test: 4.739; RMSE: val: 6.964, test: 6.677;
# |Step 9 | MAPE: val: 28.281, test: 24.404; MAE: val: 4.979, test: 4.750; RMSE: val: 6.995, test: 6.687;
# |Step 10 | MAPE: val: 28.474, test: 24.459; MAE: val: 5.002, test: 4.761; RMSE: val: 7.030, test: 6.699;
# |Step 11 | MAPE: val: 28.604, test: 24.486; MAE: val: 5.029, test: 4.775; RMSE: val: 7.060, test: 6.710;
# |Step 12 | MAPE: val: 28.761, test: 24.545; MAE: val: 5.053, test: 4.787; RMSE: val: 7.090, test: 6.721;
#
# Model  GWN  Best Results:
# Epoch 89:
# |Step 1 | MAPE: val: 27.267, test: 24.241; MAE: val: 4.859, test: 4.714; RMSE: val: 6.844, test: 6.666;
# |Step 2 | MAPE: val: 27.583, test: 24.280; MAE: val: 4.910, test: 4.750; RMSE: val: 6.901, test: 6.690;
# |Step 3 | MAPE: val: 27.692, test: 24.361; MAE: val: 4.926, test: 4.748; RMSE: val: 6.920, test: 6.695;
# |Step 4 | MAPE: val: 28.166, test: 24.490; MAE: val: 4.968, test: 4.769; RMSE: val: 6.976, test: 6.713;
# |Step 5 | MAPE: val: 28.318, test: 24.581; MAE: val: 4.994, test: 4.782; RMSE: val: 7.013, test: 6.729;
# |Step 6 | MAPE: val: 28.664, test: 24.736; MAE: val: 5.029, test: 4.798; RMSE: val: 7.063, test: 6.743;
# |Step 7 | MAPE: val: 28.693, test: 24.653; MAE: val: 5.055, test: 4.814; RMSE: val: 7.091, test: 6.756;
# |Step 8 | MAPE: val: 28.826, test: 24.735; MAE: val: 5.076, test: 4.825; RMSE: val: 7.120, test: 6.769;
# |Step 9 | MAPE: val: 29.098, test: 24.801; MAE: val: 5.114, test: 4.840; RMSE: val: 7.174, test: 6.785;
# |Step 10 | MAPE: val: 29.196, test: 24.860; MAE: val: 5.138, test: 4.856; RMSE: val: 7.189, test: 6.795;
# |Step 11 | MAPE: val: 29.559, test: 24.965; MAE: val: 5.175, test: 4.881; RMSE: val: 7.245, test: 6.814;
# |Step 12 | MAPE: val: 29.682, test: 24.996; MAE: val: 5.196, test: 4.885; RMSE: val: 7.281, test: 6.826;
#
# Model  LSTNet  Best Results:
# Epoch 170:
# |12    Horizon | MAPE: 28.685, 24.692; MAE: 5.188, 4.914; RMSE: 7.183, 6.810;
# Model Training Ended ... Sat Mar 19 17:52:21 2022
#
# Model  MTGNN  Best Results:
# Epoch 100:
# |Step 1 | MAPE: val: 26.527, test: 23.749; MAE: val: 4.725, test: 4.649; RMSE: val: 6.675, test: 6.593;
# |Step 2 | MAPE: val: 26.919, test: 23.892; MAE: val: 4.777, test: 4.674; RMSE: val: 6.738, test: 6.615;
# |Step 3 | MAPE: val: 27.179, test: 24.009; MAE: val: 4.806, test: 4.683; RMSE: val: 6.774, test: 6.626;
# |Step 4 | MAPE: val: 27.338, test: 24.033; MAE: val: 4.863, test: 4.715; RMSE: val: 6.845, test: 6.650;
# |Step 5 | MAPE: val: 27.590, test: 24.168; MAE: val: 4.882, test: 4.722; RMSE: val: 6.864, test: 6.661;
# |Step 6 | MAPE: val: 27.758, test: 24.162; MAE: val: 4.913, test: 4.734; RMSE: val: 6.907, test: 6.672;
# |Step 7 | MAPE: val: 27.941, test: 24.194; MAE: val: 4.946, test: 4.747; RMSE: val: 6.947, test: 6.684;
# |Step 8 | MAPE: val: 28.211, test: 24.343; MAE: val: 4.977, test: 4.767; RMSE: val: 6.994, test: 6.703;
# |Step 9 | MAPE: val: 28.349, test: 24.390; MAE: val: 5.005, test: 4.779; RMSE: val: 7.024, test: 6.716;
# |Step 10 | MAPE: val: 28.636, test: 24.545; MAE: val: 5.031, test: 4.793; RMSE: val: 7.054, test: 6.729;
# |Step 11 | MAPE: val: 28.810, test: 24.592; MAE: val: 5.062, test: 4.807; RMSE: val: 7.100, test: 6.743;
# |Step 12 | MAPE: val: 29.023, test: 24.670; MAE: val: 5.086, test: 4.818; RMSE: val: 7.133, test: 6.756;
#
# Model  STNorm  Best Results:
# Epoch 89:
# |Step 1 | MAPE: val: 26.291, test: 23.753; MAE: val: 4.702, test: 4.637; RMSE: val: 6.645, test: 6.576;
# |Step 2 | MAPE: val: 26.653, test: 23.873; MAE: val: 4.757, test: 4.659; RMSE: val: 6.707, test: 6.600;
# |Step 3 | MAPE: val: 26.850, test: 23.867; MAE: val: 4.788, test: 4.669; RMSE: val: 6.754, test: 6.612;
# |Step 4 | MAPE: val: 27.010, test: 23.941; MAE: val: 4.820, test: 4.683; RMSE: val: 6.787, test: 6.622;
# |Step 5 | MAPE: val: 27.349, test: 24.004; MAE: val: 4.858, test: 4.699; RMSE: val: 6.842, test: 6.639;
# |Step 6 | MAPE: val: 27.604, test: 24.100; MAE: val: 4.894, test: 4.715; RMSE: val: 6.888, test: 6.653;
# |Step 7 | MAPE: val: 27.793, test: 24.129; MAE: val: 4.928, test: 4.732; RMSE: val: 6.922, test: 6.666;
# |Step 8 | MAPE: val: 27.933, test: 24.193; MAE: val: 4.960, test: 4.749; RMSE: val: 6.970, test: 6.685;
# |Step 9 | MAPE: val: 28.223, test: 24.225; MAE: val: 4.984, test: 4.759; RMSE: val: 7.019, test: 6.698;
# |Step 10 | MAPE: val: 28.361, test: 24.318; MAE: val: 5.025, test: 4.778; RMSE: val: 7.052, test: 6.711;
# |Step 11 | MAPE: val: 28.579, test: 24.342; MAE: val: 5.041, test: 4.789; RMSE: val: 7.077, test: 6.725;
# |Step 12 | MAPE: val: 28.917, test: 24.483; MAE: val: 5.087, test: 4.812; RMSE: val: 7.133, test: 6.742;
# ```
